# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("tips.csv")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x=df["tip"],y=df["total_bill"])
plt.show()

# %%
sns.jointplot(x=df["tip"],y=df["total_bill"],hue=df["sex"])

# %%
sns.jointplot(x=df["sex"],y=df["tip"])

# %%
sns.jointplot(x=df["tip"],y=df["day"],hue=df["sex"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sns.jointplot(x=df["tip"],y=df["day"],hue=df["sex"])
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:2265, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2262         marginal_kws.setdefault("fill", True)
#    2264     marginal_kws.setdefault("color", color)
# -> 2265     grid.plot_marginals(marg_func, **marginal_kws)
#    2267 elif kind.startswith("hist"):
#    2268
#    2269     # TODO process pair parameters for bins, etc. and pass
#    2270     # to both joint and marginal plots
#    2272     joint_kws.setdefault("color", color)
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:1883, in JointGrid.plot_marginals(self, func, **kwargs)
# ...
